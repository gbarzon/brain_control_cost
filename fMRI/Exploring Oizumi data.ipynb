# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.io import loadmat

# %% [markdown]
# # Continuous dynamics

# %%
data = loadmat('Data.mat')

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'emp', 'params'])

# %%
[tmp.shape for tmp in data['emp'][0][0]]
# Out:
# [(100, 9, 100), (100, 100, 9, 100), (100, 100, 100)]

# %%
[tmp.shape for tmp in data['params'][0][0]]
# Out:
# [(100, 100, 100), (100, 100, 100)]

# %%
data['emp']['mu_tasks'][0][0].shape
# Out:
# (100, 9, 100)

# %%
data['emp']['cov_tasks'][0][0].shape
# Out:
# (100, 100, 9, 100)

# %%
data['emp']['cov_rest1'][0][0].shape
# Out:
# (100, 100, 100)

# %%
plt.imshow(data['emp']['cov_rest1'][0][0][:,:,-1])
plt.colorbar()
plt.show()

# %% [markdown]
# # Discrete dynamics

# %%
data = loadmat('demo_data.mat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except IOError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demo_data.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = loadmat('demo_data.mat')
#
# File ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py:224, in loadmat(file_name, mdict, appendmat, **kwargs)
#      87 """
#      88 Load MATLAB file.
#      89
#    (...)
#     221     3.14159265+3.14159265j])
#     222 """
#     223 variable_names = kwargs.pop('variable_names', None)
# ...

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Data'])

# %%
data['Data']['probDists'][0][0].shape
# Out:
# (9, 8)

# %%
states = np.load('results/best_maps.npy')

# %%
states.shape
# Out:
# (9, 64)

# %%
np.savetxt('best_maps.csv', states, delimiter=',')
